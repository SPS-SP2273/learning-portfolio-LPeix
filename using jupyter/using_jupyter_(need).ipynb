# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Need)</span></div>

# %%
# !dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 462B-2151
#
#  Directory of C:\Users\Liu Peixuan\OneDrive\??\learning-portfolio-LPeix\using jupyter
#
# 19/01/2024  17:06    <DIR>          .
# 17/01/2024  13:17    <DIR>          ..
# 19/01/2024  16:26    <DIR>          .ipynb_checkpoints
# 17/01/2024  08:41             2,512 using_jupyter_(good).ipynb
# 19/01/2024  17:06             3,759 using_jupyter_(need).ipynb
#                2 File(s)          6,271 bytes
#                3 Dir(s)  310,110,560,256 bytes free

# %% [markdown]
# - basic unit of Jupyter Note book = cell
# - code cell = accept code
# - markdown cell = render text
# - run a cell = `CTRL + ENTER`
#
# ### keyboard shortcut
# | Action | Shortcut |
# | ---- | ---- |
# | Run cell | `CTRL + ENTER` or `CMD + ENTER` |
# | Run cell and move to the next | `SHIFT + ENTER` |
# | Select one/more cells | `SHIFT + UP/DOWN ARROW` |
# | Convert cell to code cell | `ESC + Y` |
# | Convert cell to Markdown cell | `ESC + M` |
# | Create new cell | `ESC + A` (above)  <br>`ESC + B` (below) |
# | Copy cell(s) | `ESC + C` |
# | Paste cell(s) | `ESC + V` |
# | Merge cells | `SHIFT + M` |
# | Delete cell | `ESC + D + D` |
# | Show/view/set shortcuts | `ESC + H`/`CTRL + SHIFT + H` |
# | Another line | `SPACE x 2`/`SPACE \` |
# shortcut commands use the escape button (`ESC`)
# typing `ESC` puts Jupyter into command mode, ready for a command, not code or text.
#
# ### shell commands
# run shell commands from Jupyter w/o switching to the terminal
# add `!` in front of the command
#
# - This will print the current working directory.
#
#     ```
#     !cd
#     ```
#
# - This will show you a list of all the files in your folder.
#
#     ```
#     !dir
#     ```
#
# ### Jupyter extentions
# install [Jupyter extension](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/) from terminal by:
# ```
# conda install -c conda-forge jupyter_contrib_nbextensions
# ```
#
# ```
# jupyter contrib nbextension install --user
# ```
# finished installing, log out and restart Jupyter
# see details of what each extension does by clicking on the name in the list
# enable them simply by checking the box on the list
# **recommended extension list**
# 	1. Equation Auto Numbering
# 	2. Table of Contents (2)
# 	3. Variable Inspector
# 	4. Code folding
# 	5. Autopep8
# 	    You must install the package `autopep8` using `conda` for this to work.
#
# ### shell magic
# **line magic**
# ```
# %timeit x=10
# ```
#
# tell you statistics on how long the command takes to execute
# works (i.e., does the timing in this case) for only a single line
#
# **cell magic** command `%%timeit`.
#
# ```
# %%timeit
# x=10
# y=10
# z=10
# ```
# apply it to a whole cell
#
# Use `%lsmagic` to discover what else is available.
# ### the kernel
# = the core program of the operating system
# **interrupt, restart,** or **shut down** the kernel using the `Kernel` button in the toolbar
#
# ### Markdown
# select a code cell --> markdown cell `ESC + M`
# #### basic syntax
# | Style | Syntax |
# | :--- | ---- |
# | Bold | `** **` or `__ __` |
# |Italic|`* *` or `_ _`|
# |All bold and italic|`*** ***`|
# |Subscript|`<sub> </sub>`|
# |Superscript|`<sup> </sup>`|
# e.g. `The ships *hung in the sky* in much the same way that **bricks don’t.**<sup>1</sup><sub>QUOTE</sub>`
# The ships *hung in the sky* in much the same way that **bricks don’t.**<sup>1</sup><sub>QUOTE</sub>
#
# #### headings
# `# The largest heading`
# `## The second-largest heading`
# `### The third-largest heading`
# `#### The smallest heading`
#
# #### code block
# use```in front and after
# language (e.g. python, js) after ``` to specify syntax highliting
# ```python
# print('hello world!')
# ```
#
# #### links
# `[SP2273 Website](https://sps.nus.edu.sg/sp2273)`
# This will be rendered as [SP2273 Website](https://sps.nus.edu.sg/sp2273)
# **!!!** always rmmb to include the 'https://' part
#
# #### images
# `![alternate text for image](https://nus.edu.sg/images/default-source/base/logo.png)`
# this will give you
# ![](https://nus.edu.sg/images/default-source/base/logo.png)
#
# #### tables
# `| A | B | C |`
# `| :--- | :--: | ---: |`
# `| a1 | b1 | c1 |`
# `| a2 | b2 | c2 |`
# `| a3 | b3 | c3 |`
# this will give you
#
# | A | B | C |
# | :--- | :--: | ---: |
# | a1 | b1 | c1 |
# | a2 | b2 | c2 |
# | a3 | b3 | c3 |
#
# `:--` = left-justified
# `:-:` = centre-justified
# `--:` = right-justified
# with larger table, use Excel or Sheets then copy into [Table Generator](https://www.tablesgenerator.com/)
# #### list
# use `-` for point
# use `1.` for number
#
# #### equations
# markdown use *LATEX* engine called *MathJax*
#
# inline math use  \$
# `$\sqrt{b^2-4ac}$`
# rendered as $\sqrt{b^2-4ac}$
#
# math block use \$$
# `$$ x = \dfrac{-b \pm \sqrt{b^2-4ac}}{2a} $$`
# rendered as
# $$ x = \dfrac{-b \pm \sqrt{b^2-4ac}}{2a} $$
# more maths commands refer to [Over leaf mathematical documentation](https://www.overleaf.com/learn/latex/Mathematical_expressions)
#
# | Input | Rendered |  |
# | ---- | ---- | ---- |
# | Fraction | `$\dfrac{y}{x}$` | $\dfrac{y}{x}$ |
# | Subscript | `$x_{a}$` | $x_{a}$ |
# | Power | `$x^{(y+z)}$` | $x^{(y+z)}$ |
# | Squareroot | `$\sqrt{a+b+c}$` | $\sqrt{a+b+c}$ |
# | Sum | `$\sum_{n=1}^{n=\infty} x_n$` | $\sum_{n=1}^{n=\infty} x_n$ |
# | Integral | `$\int_{x=1}^{x=\infty} f(x)dx$` | $\int_{x=1}^{x=\infty} f(x)dx$ |
# | Not equal | `$a \ne b$` | $a \ne b$ |
# | Less than | `$a \lt b$` | $a \lt b$ |
# | Less than or equal to | `$a \leq b$` | $a \leq b$ |
# | Greater than | `$a \gt b$` | $a \gt b$ |
# | Greater than or equal to | `$a \geq b$` | $a \geq b$ |
# | Greek letters<br>*mind the capital* | `$\alpha, \beta, \gamma, \pi, \lambda$`<br>`$\delta, \Delta$` | $\alpha, \beta, \gamma, \pi, \lambda$<br>$\delta, \Delta$ |
# #### footnote
# `this is a footnote[^1]`
# `[^1]: this will be the foot note!`
#
# this is a footnote[^1]
#
# [^1]: this will be the foot note!
#
# #### remove noise through GitHub Desktop
# repository > repository settings > ignored files
# `**/.ipynb_checkpoints/**`
#
# yellow icon - change made
# green icon - no change
